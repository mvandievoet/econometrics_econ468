# %%
import pandas as pd

df = pd.read_csv('e468_midterm_20.txt', sep='  ')
# Out:
# <ipython-input-7-0d436a52239e>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('e468_midterm_20.txt', sep='  ')
#              Y           C
# 0    81.173725   79.668528
# 1   152.939116  168.455894
# 2    91.776628  109.836698
# 3   122.152903  126.605400
# 4    86.937168   83.014005
# ..         ...         ...
# 95  122.881481  138.034938
# 96   80.673216   78.322414
# 97  146.854190  143.745071
# 98   89.988631  102.053823
# 99  126.995091  127.665735
#
# [100 rows x 2 columns]

# %%
from statsmodels.formula.api import ols
import numpy as np

# %%
fit1 = ols('C ~ Y', data=df).fit()
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      C   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     465.6
# Date:                Sun, 18 Oct 2020   Prob (F-statistic):           5.21e-39
# Time:                        22:43:08   Log-Likelihood:                -380.19
# No. Observations:                 100   AIC:                             764.4
# Df Residuals:                      98   BIC:                             769.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.3289      4.829      2.553      0.012       2.747      21.911
# ...

# %%
s1,s2,s3,s4 = np.full(100, 0), np.full(100, 0), np.full(100, 0), np.full(100, 0)

i=0
while i<100:
    s1[i], s2[i+1], s3[i+2], s4[i+3] = 1, 1, 1, 1
    i += 4
    
df['s1'], df['s2'], df['s3'], df['s4'] = s1, s2, s3, s4

# %%
fit2 = ols('C ~ s1 + s2 + s3 + s4 + Y -1', data=df).fit()
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      C   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     178.0
# Date:                Sun, 18 Oct 2020   Prob (F-statistic):           3.15e-43
# Time:                        23:55:36   Log-Likelihood:                -360.69
# No. Observations:                 100   AIC:                             731.4
# Df Residuals:                      95   BIC:                             744.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# s1            16.7515     14.032      1.194      0.236     -11.106      44.609
# ...

# %%
fit3 = ols('C ~ s1 + s2 + s3 + s4 -1', data=df).fit()
df['residuals_consumption'] = fit3.resid
fit4 = ols('Y ~ s1 + s2 + s3 + s4 -1', data=df).fit()
df['residuals_income'] = fit4.resid

# %%
fit5 = ols('residuals_consumption ~ residuals_income -1', data=df).fit()
fit5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ...
# Dep. Variable:     residuals_consumption   R-squared (uncentered):                   0.201
# Model:                               OLS   Adj. R-squared (uncentered):              0.193
# Method:                    Least Squares   F-statistic:                              24.85
# Date:                   Sun, 18 Oct 2020   Prob (F-statistic):                    2.64e-06
# Time:                           23:39:28   Log-Likelihood:                         -360.69
# No. Observations:                    100   AIC:                                      723.4
# Df Residuals:                         99   BIC:                                      726.0
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
df['sn1'], df['sn2'], df['sn3'], = df.s1 - df.s4, df.s2 - df.s4, df.s3 - df.s4

# %%
fit6 = ols('C ~ sn1 + sn2 + sn3 + Y', data=df).fit()
fit6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      C   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     178.0
# Date:                Sun, 18 Oct 2020   Prob (F-statistic):           3.15e-43
# Time:                        23:58:51   Log-Likelihood:                -360.69
# No. Observations:                 100   AIC:                             731.4
# Df Residuals:                      95   BIC:                             744.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     21.7475     18.874      1.152      0.252     -15.722      59.217
# ...
